# %%
import pandas as pd
import matplotlib as plt 
import seaborn as sns 
import numpy as np

# %%
df_cancel = pd.read_csv('/Users/pierreloyal/Downloads/us_flight_2023/Cancelled_Diverted_2023.csv')

# %%
df_cancel.shape
# Out:
# (104488, 23)

# %%
df_cancel.head()
# Out:
#    FlightDate  Day_Of_Week       Airline Tail_Number  Cancelled  Diverted  \
# 0  2023-01-25            3  Endeavor Air      N691CA        1.0       0.0
# 1  2023-01-03            2  Endeavor Air      N937XJ        1.0       0.0
# 2  2023-01-03            2  Endeavor Air      N937XJ        1.0       0.0
# 3  2023-01-11            3  Endeavor Air      N926XJ        1.0       0.0
# 4  2023-01-25            3  Endeavor Air      N335PQ        0.0       1.0
#
#   Dep_Airport     Dep_CityName DepTime_label  Dep_Delay  ...  \
# 0         JFK     New York, NY       Evening        0.0  ...
# 1         MSP  Minneapolis, MN       Morning        0.0  ...
# 2         PIT   Pittsburgh, PA     Afternoon        0.0  ...
# 3         BWI    Baltimore, MD     Afternoon        0.0  ...
# 4         BWI    Baltimore, MD     Afternoon        2.0  ...
#
#           Arr_CityName Arr_Delay    Arr_Delay_Type Flight_Duration  \
# 0  Ithaca/Cortland, NY       0.0  No Arrival Delay             0.0
# ...

# %%
df_cancel.tail()
# Out:
#         FlightDate  Day_Of_Week          Airline Tail_Number  Cancelled  \
# 104483  2023-12-29            5  JetBlue Airways      N206JB        1.0
# 104484  2023-12-29            5  JetBlue Airways      N636JB        1.0
# 104485  2023-12-29            5  JetBlue Airways      N661JB        0.0
# 104486  2023-12-29            5  JetBlue Airways      N216JB        1.0
# 104487  2023-12-31            7  JetBlue Airways      N952JB        0.0
#
#         Diverted Dep_Airport         Dep_CityName DepTime_label  Dep_Delay  \
# 104483       0.0         BTV       Burlington, VT       Morning        0.0
# 104484       0.0         FLL  Fort Lauderdale, FL       Evening        0.0
# 104485       1.0         TPA            Tampa, FL       Evening      122.0
# 104486       0.0         DCA       Washington, DC       Morning        0.0
# 104487       1.0         SAN        San Diego, CA       Evening      125.0
#
#         ...      Arr_CityName Arr_Delay    Arr_Delay_Type Flight_Duration  \
# ...

# %%
row_999999 = df_cancel.loc[94699]
row_999999
# Out:
# FlightDate                        2023-09-06
# Day_Of_Week                                3
# Airline               Southwest Airlines Co.
# Tail_Number                           N8833L
# Cancelled                                1.0
# Diverted                                 0.0
# Dep_Airport                              MDW
# Dep_CityName                     Chicago, IL
# DepTime_label                        Morning
# Dep_Delay                                0.0
# Dep_Delay_Tag                              0
# Dep_Delay_Type            No Departure Delay
# Arr_Airport                              PHX
# Arr_CityName                     Phoenix, AZ
# Arr_Delay                                0.0
# Arr_Delay_Type              No Arrival Delay
# Flight_Duration                          0.0
# Distance_type                     Short Haul
# Delay_Carrier                            0.0
# Delay_Weather                            0.0
# Delay_NAS                                0.0
# ...
